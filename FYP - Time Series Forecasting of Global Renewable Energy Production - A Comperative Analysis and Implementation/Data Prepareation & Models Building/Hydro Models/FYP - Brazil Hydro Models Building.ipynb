# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import math

# %% [markdown]
# # Read Hydro Energy Production Dataset

# %%
data = pd.read_csv('F:\APU\FYP\Dataset\Cleaned_data\hydro_production_dataset.csv')

data.head()
# Out:
#      Country        Date      Value  Precipitation
# 0  Australia  2023-03-01  1215.8041       0.080641
# 1  Australia  2023-02-01   942.5558       0.127869
# 2  Australia  2023-01-01  1190.7296       0.159242
# 3  Australia  2022-12-01  1110.1523       0.105662
# 4  Australia  2022-11-01  1397.5839       0.073524

# %% [markdown]
# ## Extract Data for each country

# %%
countries = data['Country'].unique()

hydro_production_data = {}

# use loc() function to select data from a DataFrame based on specified row and column labels or conditions.
# Iterate over the countries
for country in countries:
    # Filter the data for the current country and 'Hydro' product
    country_energy_production = data.loc[
        (data['Country'] == country), ['Date', 'Value', 'Precipitation']
    ]
    
    # Store the filtered data in the dictionary
    hydro_production_data[country] = country_energy_production.reset_index(drop=True)

hydro_production_data['Brazil']
# Out:
#           Date       Value  Precipitation
# 0   2023-03-01  42125.0402       0.311849
# 1   2023-02-01  37537.4705       0.309499
# 2   2023-01-01  40131.3684       0.310632
# 3   2022-12-01  37731.9933       0.301121
# 4   2022-11-01  33992.2079       0.225746
# ..         ...         ...            ...
# 94  2015-05-01  28657.9530       0.210786
# 95  2015-04-01  29569.5100       0.263281
# 96  2015-03-01  32357.8210       0.344330
# 97  2015-02-01  30085.6360       0.319078
# 98  2015-01-01  34343.3740       0.248368
#
# [99 rows x 3 columns]

# %% [markdown]
# # Resample to daily data

# %%
# hypro_production_data
for country_data in hydro_production_data:
    
    # set time as the index
    hydro_production_data[country_data]['Date'] = pd.to_datetime(hydro_production_data[country_data]['Date'])
    hydro_production_data[country_data].set_index('Date', inplace=True)
    
    # divide the monthly statistical production value by the number of days 
    # of the month to get the avarage daily production value
    hydro_production_data[country_data]['Value'] = (hydro_production_data[country_data]['Value']/
                                                    hydro_production_data[country_data].index.days_in_month)
    
    # resample the monthly index to daily and impute the missing value with linear interpolate method
    daily_data = hydro_production_data[country_data].resample('D').interpolate('linear')
    hydro_production_data[country_data] = daily_data
    
hydro_production_data['Brazil']
# Out:
#                   Value  Precipitation
# Date
# 2015-01-01  1107.850774       0.248368
# 2015-01-02  1106.774523       0.250649
# 2015-01-03  1105.698273       0.252930
# 2015-01-04  1104.622022       0.255211
# 2015-01-05  1103.545771       0.257492
# ...                 ...            ...
# 2023-02-25  1356.265362       0.311514
# 2023-02-26  1356.917088       0.311598
# 2023-02-27  1357.568813       0.311681
# 2023-02-28  1358.220539       0.311765
# 2023-03-01  1358.872265       0.311849
#
# [2982 rows x 2 columns]

# %% [markdown]
# ## Split Train and Test Data

# %%
data = hydro_production_data['Brazil']

# Split the data into training and testing sets
split_date = '2021-01-01'
train, test = data[:split_date][['Value']], data[split_date:][['Value']]

print(train.head())
print(train.shape)
print()
print(test.head())
print(test.shape)
# Out:
#                   Value
# Date
# 2015-01-01  1107.850774
# 2015-01-02  1106.774523
# 2015-01-03  1105.698273
# 2015-01-04  1104.622022
# 2015-01-05  1103.545771
# (2193, 1)
#
#                   Value
# Date
# 2021-01-01  1081.207087
# 2021-01-02  1085.324484
# 2021-01-03  1089.441881
# 2021-01-04  1093.559278
# 2021-01-05  1097.676675
# (790, 1)

# %% [markdown]
# # Univaraite - ARIMA

# %% [markdown]
# #### The developer has use R with the auto.arima() function to identify the p, q, d value of the best fit ARIMA model for this dataset, the result shows that the order(p, q, d) = (1,1,0)(0,1,0)[365]
# #### Figure below show the result from R:
# ![image.png](attachment:image.png)

# %%
import rpy2.robjects as robjects
# Load the 'forecast' R package
robjects.r("library(forecast)")

# Load the ARIMA model
r_load = robjects.r['readRDS']
brz_hydro_arima_model = r_load(r"F:\APU\FYP\SEM 2\Report Doc\R script\brz_hydro_arima_model.rds")

# %%
# Generate predictions
r_forecast = robjects.r['forecast']
predictions = r_forecast(brz_hydro_arima_model, h=len(test))

# Evaluate the model performance
print("Mean Absolute Error: ", mean_absolute_error(predictions.rx('mean')[0], test.values))
mse = mean_squared_error(predictions.rx('mean')[0], test.values)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ", math.sqrt(mse))
# Out:
# Mean Absolute Error:  312.4786935669045
# Mean Squared Error:  132661.4110553219
# Root Mean Squared Error:  364.22714211782994

# %%
# Visualising the results
plt.figure(figsize=(20,5))
plt.plot(test.values, color = 'red', label = 'Real Hydro Energy Production')
plt.plot(predictions.rx('mean')[0], color = 'blue', label = 'Predicted Hydro Energy Production')
plt.title('Brazil Hydro Energy Production ARIMA Prediction')
plt.xlabel('Time')
plt.ylabel('Hydro Energy Production (GWh)')
plt.legend()
plt.show()

# %% [markdown]
# ## Univariate - SVR - Daily

# %%
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler

# %%
# Feature Scaling
scaler = MinMaxScaler(feature_range=(0, 1))
train_scaled = scaler.fit_transform(train[['Value']].values)
test_scaled = scaler.transform(test[['Value']].values)

# Reshape the input data to fit
time_steps = 365  # Define the number of previous time steps to consider

# Creating a data structure with 365 timestamps and 1 output
x_train = []
y_train = []
for i in range(time_steps, len(train)):
    x_train.append(train_scaled[i-time_steps:i, 0])
    y_train.append(train_scaled[i, 0])
x_train, y_train = np.array(x_train), np.array(y_train)

print(x_train.shape, y_train.shape)
# Out:
# (1828, 365) (1828,)

# %%
# Build and Train the SVM Model
brz_daily_svr = SVR(kernel='linear',gamma=0.5, C=10, epsilon = 0.01)
brz_daily_svr.fit(x_train, y_train)
# Out:
# SVR(C=10, epsilon=0.01, gamma=0.5, kernel='linear')

# %%
dataset_total = pd.concat((train['Value'], test['Value']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - 365:].values
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)
x_test = []
for i in range(time_steps, len(test)+time_steps):
    x_test.append(inputs[i-time_steps:i, 0])
x_test = np.array(x_test)

# Predict Hydro Energy Production
svr_y_pred = brz_daily_svr.predict(x_test).reshape(-1,1)
svr_y_pred = scaler.inverse_transform(svr_y_pred)
print(svr_y_pred.shape)
# Out:
# (790, 1)

# %%
# Evaluate the model
print("Mean Absolute Error: ", mean_absolute_error(svr_y_pred, test['Value'].values))
mse = mean_squared_error(svr_y_pred, test['Value'].values)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ",math.sqrt(mse))
# Out:
# Mean Absolute Error:  3.673266300848552
# Mean Squared Error:  21.16135420335652
# Root Mean Squared Error:  4.600147193662016

# %%
# Visualising the results
plt.figure(figsize=(20,5))
plt.plot(test['Value'].values, color='red', label='Real Value')
plt.plot(svr_y_pred, color='blue', label='Predicted Value')
plt.title('Brazil Hydro Energy SVR Prediction')
plt.xlabel('Time')
plt.ylabel('Hydro Energy (GWh)')
plt.legend()
plt.show()

# %% [markdown]
# ## Univariate ANN - Daily

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(train.values)

# %%
def create_dataset(data, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i+time_steps])
        y.append(data[i+time_steps])
    return np.array(X), np.array(y)

# Set the number of time steps (input sequence length)
time_steps = 365

# Create the training datasets
X_train, y_train = create_dataset(training_set_scaled, time_steps)

# Create the testing datasets
X_test, y_test = create_dataset(test.values, time_steps)

X_train.shape
# Out:
# (1828, 365, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from keras.layers import Dropout

# Create the model
brz_daily_ann = Sequential()
brz_daily_ann.add(Dense(84, activation='tanh', input_shape=(365,)))
brz_daily_ann.add(Dropout(0.2))
brz_daily_ann.add(Dense(1, activation='linear'))

brz_daily_ann.compile(optimizer='adam', loss='mean_squared_error')

brz_daily_ann.fit(X_train, y_train, epochs=100, batch_size=16)
# Out:
# Epoch 1/100
# 115/115 [==============================] - 8s 3ms/step - loss: 0.1459
# Epoch 2/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0416
# Epoch 3/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0191
# Epoch 4/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0116
# Epoch 5/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 6/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0070
# Epoch 7/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0087
# Epoch 8/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0104
# Epoch 9/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 10/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 11/100
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0055
# Epoch 12/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 13/100
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0041
# Epoch 14/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 15/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 16/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 17/100
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0056
# Epoch 18/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 19/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0026
# Epoch 20/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0028
# Epoch 21/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 22/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 23/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 24/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 25/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 26/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 27/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0019
# Epoch 28/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 29/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 30/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 31/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0019
# Epoch 32/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 33/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 34/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 35/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 36/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 37/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 38/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0016
# Epoch 39/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0020
# Epoch 40/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 41/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 42/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 43/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 44/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 45/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 46/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 47/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 48/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 49/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0018
# Epoch 50/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 51/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 52/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 53/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 54/100
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 55/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 56/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 57/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 58/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 59/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 60/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 61/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 62/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0015
# Epoch 63/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 64/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 65/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.8142e-04
# Epoch 66/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 67/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 68/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 69/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0014
# Epoch 70/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 71/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 72/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 73/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 74/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 75/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 76/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 77/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 78/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 79/100
# 115/115 [==============================] - 0s 2ms/step - loss: 9.5844e-04
# Epoch 80/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 81/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.3061e-04
# Epoch 82/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.3754e-04
# Epoch 83/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 84/100
# 115/115 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 85/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.9389e-04
# Epoch 86/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.1513e-04
# Epoch 87/100
# 115/115 [==============================] - 0s 2ms/step - loss: 9.7980e-04
# Epoch 88/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 89/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 90/100
# 115/115 [==============================] - 1s 5ms/step - loss: 9.7012e-04
# Epoch 91/100
# 115/115 [==============================] - 0s 2ms/step - loss: 8.8044e-04
# Epoch 92/100
# 115/115 [==============================] - 0s 2ms/step - loss: 9.1717e-04
# Epoch 93/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.3987e-04
# Epoch 94/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.2108e-04
# Epoch 95/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 96/100
# 115/115 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 97/100
# 115/115 [==============================] - 1s 5ms/step - loss: 0.0010
# Epoch 98/100
# 115/115 [==============================] - 0s 3ms/step - loss: 0.0013
# Epoch 99/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.9941e-04
# Epoch 100/100
# 115/115 [==============================] - 0s 3ms/step - loss: 9.3135e-04

# %%
dataset_total = pd.concat((train['Value'], test['Value']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - 365:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(time_steps, len(test)+time_steps):
    X_test.append(inputs[i-time_steps:i])
X_test = np.array(X_test)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1])

ann_y_pred = brz_daily_ann.predict(X_test)
ann_y_pred = sc.inverse_transform(ann_y_pred)

print("Mean Absolute Error: ", mean_absolute_error(ann_y_pred, test.values))
mse = mean_squared_error(ann_y_pred, test.values)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ",math.sqrt(mse))
# Out:
# 25/25 [==============================] - 4s 24ms/step
# Mean Absolute Error:  14.444807732008401
# Mean Squared Error:  340.81026826678993
# Root Mean Squared Error:  18.4610473231285

# %%
# Visualising the results
plt.figure(figsize=(20,5))
plt.plot(test.values, color = 'red', label = 'Real Hydro Energy Production')
plt.plot(ann_y_pred, color = 'blue', label = 'Predicted Hydro Energy Production')
plt.title('Brazil Hydro Energy ANN Prediction')
plt.xlabel('Time')
plt.ylabel('Hydro Energy (GWh)')
plt.legend()
plt.show()

# %% [markdown]
# ## Univariate LSTM - Daily

# %%
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(train.values)

print(training_set_scaled)
print(training_set_scaled.shape)
# Out:
# [[0.55071165]
#  [0.54852652]
#  [0.54634139]
#  ...
#  [0.4893988 ]
#  [0.49300771]
#  [0.49661662]]
# (2193, 1)

# %%
# Creating a data structure with 365 timestamps and 1 output
X_train = []
y_train = []
for i in range(time_steps, len(train)):
    X_train.append(training_set_scaled[i-365:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
print(X_train)
X_train.shape
# Out:
# [[0.55071165 0.54852652 0.54634139 ... 0.45864168 0.46322324 0.4678048 ]
#  [0.54852652 0.54634139 0.54415627 ... 0.46322324 0.4678048  0.47238636]
#  [0.54634139 0.54415627 0.54197114 ... 0.4678048  0.47238636 0.4760173 ]
#  ...
#  [0.71336441 0.7218354  0.72786224 ... 0.47857208 0.48218099 0.4857899 ]
#  [0.7218354  0.72786224 0.73388909 ... 0.48218099 0.4857899  0.4893988 ]
#  [0.72786224 0.73388909 0.73991593 ... 0.4857899  0.4893988  0.49300771]]
# (1828, 365)

# %%
print(y_train)
y_train.shape
# Out:
# [0.47238636 0.4760173  0.47964825 ... 0.4893988  0.49300771 0.49661662]
# (1828,)

# %%
# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
# Building the RNN

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# Initialising the RNN
brz_daily_uni_lstm = Sequential()

# Adding the first LSTM layer and some Dropout regularisation
brz_daily_uni_lstm.add(LSTM(units = 64, return_sequences = True, input_shape = (X_train.shape[1], 1)))
brz_daily_uni_lstm.add(Dropout(0.2))

brz_daily_uni_lstm.add(LSTM(units = 64, return_sequences = True))
brz_daily_uni_lstm.add(Dropout(0.2))

brz_daily_uni_lstm.add(LSTM(units = 64))
brz_daily_uni_lstm.add(Dropout(0.2))

# Adding the output layer
brz_daily_uni_lstm.add(Dense(units = 1))

# %%
# Compiling the RNN
brz_daily_uni_lstm.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
brz_daily_uni_lstm.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 110s 665ms/step - loss: 0.0181
# Epoch 2/100
# 58/58 [==============================] - 38s 657ms/step - loss: 0.0038
# Epoch 3/100
# 58/58 [==============================] - 41s 704ms/step - loss: 0.0031
# Epoch 4/100
# 58/58 [==============================] - 39s 667ms/step - loss: 0.0025
# Epoch 5/100
# 58/58 [==============================] - 41s 704ms/step - loss: 0.0023
# Epoch 6/100
# 58/58 [==============================] - 37s 639ms/step - loss: 0.0023
# Epoch 7/100
# 58/58 [==============================] - 38s 660ms/step - loss: 0.0022
# Epoch 8/100
# 58/58 [==============================] - 41s 707ms/step - loss: 0.0018
# Epoch 9/100
# 58/58 [==============================] - 44s 757ms/step - loss: 0.0017
# Epoch 10/100
# 58/58 [==============================] - 46s 793ms/step - loss: 0.0018
# Epoch 11/100
# 58/58 [==============================] - 47s 819ms/step - loss: 0.0016
# Epoch 12/100
# 58/58 [==============================] - 49s 848ms/step - loss: 0.0015
# Epoch 13/100
# 58/58 [==============================] - 47s 815ms/step - loss: 0.0016
# Epoch 14/100
# 58/58 [==============================] - 48s 832ms/step - loss: 0.0014
# Epoch 15/100
# 58/58 [==============================] - 50s 857ms/step - loss: 0.0013
# Epoch 16/100
# 58/58 [==============================] - 51s 885ms/step - loss: 0.0016
# Epoch 17/100
# 58/58 [==============================] - 49s 847ms/step - loss: 0.0017
# Epoch 18/100
# 58/58 [==============================] - 46s 787ms/step - loss: 0.0013
# Epoch 19/100
# 58/58 [==============================] - 46s 789ms/step - loss: 0.0012
# Epoch 20/100
# 58/58 [==============================] - 46s 796ms/step - loss: 0.0016
# Epoch 21/100
# 58/58 [==============================] - 53s 917ms/step - loss: 0.0013
# Epoch 22/100
# 58/58 [==============================] - 55s 946ms/step - loss: 0.0011
# Epoch 23/100
# 58/58 [==============================] - 57s 976ms/step - loss: 0.0012
# Epoch 24/100
# 58/58 [==============================] - 52s 900ms/step - loss: 0.0012
# Epoch 25/100
# 58/58 [==============================] - 58s 986ms/step - loss: 0.0013
# Epoch 26/100
# 58/58 [==============================] - 56s 956ms/step - loss: 9.9655e-04
# Epoch 27/100
# 58/58 [==============================] - 53s 914ms/step - loss: 0.0010
# Epoch 28/100
# 58/58 [==============================] - 51s 874ms/step - loss: 0.0010
# Epoch 29/100
# 58/58 [==============================] - 45s 782ms/step - loss: 0.0012
# Epoch 30/100
# 58/58 [==============================] - 44s 767ms/step - loss: 0.0013
# Epoch 31/100
# 58/58 [==============================] - 45s 785ms/step - loss: 9.6505e-04
# Epoch 32/100
# 58/58 [==============================] - 51s 879ms/step - loss: 0.0011
# Epoch 33/100
# 58/58 [==============================] - 44s 759ms/step - loss: 9.2968e-04
# Epoch 34/100
# 58/58 [==============================] - 47s 811ms/step - loss: 8.3442e-04
# Epoch 35/100
# 58/58 [==============================] - 44s 751ms/step - loss: 0.0010
# Epoch 36/100
# 58/58 [==============================] - 44s 758ms/step - loss: 0.0011
# Epoch 37/100
# 58/58 [==============================] - 45s 777ms/step - loss: 9.8346e-04
# Epoch 38/100
# 58/58 [==============================] - 44s 761ms/step - loss: 8.1712e-04
# Epoch 39/100
# 58/58 [==============================] - 45s 776ms/step - loss: 0.0010
# Epoch 40/100
# 58/58 [==============================] - 45s 775ms/step - loss: 8.7569e-04
# Epoch 41/100
# 58/58 [==============================] - 48s 831ms/step - loss: 7.7747e-04
# Epoch 42/100
# 58/58 [==============================] - 45s 781ms/step - loss: 9.1284e-04
# Epoch 43/100
# 58/58 [==============================] - 48s 827ms/step - loss: 8.5509e-04
# Epoch 44/100
# 58/58 [==============================] - 42s 730ms/step - loss: 8.0569e-04
# Epoch 45/100
# 58/58 [==============================] - 47s 821ms/step - loss: 7.1929e-04
# Epoch 46/100
# 58/58 [==============================] - 47s 814ms/step - loss: 8.2359e-04
# Epoch 47/100
# 58/58 [==============================] - 45s 779ms/step - loss: 7.8678e-04
# Epoch 48/100
# 58/58 [==============================] - 49s 845ms/step - loss: 7.3817e-04
# Epoch 49/100
# 58/58 [==============================] - 48s 825ms/step - loss: 7.4631e-04
# Epoch 50/100
# 58/58 [==============================] - 48s 818ms/step - loss: 6.7434e-04
# Epoch 51/100
# 58/58 [==============================] - 47s 812ms/step - loss: 7.9550e-04
# Epoch 52/100
# 58/58 [==============================] - 44s 756ms/step - loss: 7.1394e-04
# Epoch 53/100
# 58/58 [==============================] - 44s 766ms/step - loss: 6.5089e-04
# Epoch 54/100
# 58/58 [==============================] - 45s 784ms/step - loss: 6.9669e-04
# Epoch 55/100
# 58/58 [==============================] - 49s 845ms/step - loss: 6.7867e-04
# Epoch 56/100
# 58/58 [==============================] - 49s 843ms/step - loss: 6.6756e-04
# Epoch 57/100
# 58/58 [==============================] - 47s 806ms/step - loss: 7.0361e-04
# Epoch 58/100
# 58/58 [==============================] - 46s 785ms/step - loss: 6.5352e-04
# Epoch 59/100
# 58/58 [==============================] - 43s 746ms/step - loss: 6.6113e-04
# Epoch 60/100
# 58/58 [==============================] - 43s 742ms/step - loss: 6.2794e-04
# Epoch 61/100
# 58/58 [==============================] - 44s 760ms/step - loss: 6.9402e-04
# Epoch 62/100
# 58/58 [==============================] - 44s 762ms/step - loss: 7.0758e-04
# Epoch 63/100
# 58/58 [==============================] - 51s 881ms/step - loss: 6.4520e-04
# Epoch 64/100
# 58/58 [==============================] - 47s 814ms/step - loss: 7.0853e-04
# Epoch 65/100
# 58/58 [==============================] - 48s 819ms/step - loss: 6.1346e-04
# Epoch 66/100
# 58/58 [==============================] - 51s 872ms/step - loss: 6.6157e-04
# Epoch 67/100
# 58/58 [==============================] - 52s 900ms/step - loss: 5.9733e-04
# Epoch 68/100
# 58/58 [==============================] - 52s 906ms/step - loss: 6.7813e-04
# Epoch 69/100
# 58/58 [==============================] - 48s 827ms/step - loss: 6.1947e-04
# Epoch 70/100
# 58/58 [==============================] - 45s 784ms/step - loss: 7.6182e-04
# Epoch 71/100
# 58/58 [==============================] - 45s 773ms/step - loss: 5.9705e-04
# Epoch 72/100
# 58/58 [==============================] - 45s 775ms/step - loss: 5.4672e-04
# Epoch 73/100
# 58/58 [==============================] - 45s 772ms/step - loss: 5.8914e-04
# Epoch 74/100
# 58/58 [==============================] - 50s 870ms/step - loss: 6.0108e-04
# Epoch 75/100
# 58/58 [==============================] - 45s 775ms/step - loss: 5.9724e-04
# Epoch 76/100
# 58/58 [==============================] - 45s 786ms/step - loss: 6.0395e-04
# Epoch 77/100
# 58/58 [==============================] - 44s 760ms/step - loss: 5.7387e-04
# Epoch 78/100
# 58/58 [==============================] - 45s 783ms/step - loss: 5.8919e-04
# Epoch 79/100
# 58/58 [==============================] - 44s 762ms/step - loss: 5.3196e-04
# Epoch 80/100
# 58/58 [==============================] - 47s 814ms/step - loss: 6.4117e-04
# Epoch 81/100
# 58/58 [==============================] - 49s 852ms/step - loss: 5.6646e-04
# Epoch 82/100
# 58/58 [==============================] - 46s 792ms/step - loss: 5.2709e-04
# Epoch 83/100
# 58/58 [==============================] - 46s 792ms/step - loss: 5.9986e-04
# Epoch 84/100
# 58/58 [==============================] - 46s 801ms/step - loss: 5.4659e-04
# Epoch 85/100
# 58/58 [==============================] - 48s 825ms/step - loss: 5.6913e-04
# Epoch 86/100
# 58/58 [==============================] - 46s 797ms/step - loss: 5.7491e-04
# Epoch 87/100
# 58/58 [==============================] - 45s 778ms/step - loss: 6.8674e-04
# Epoch 88/100
# 58/58 [==============================] - 50s 856ms/step - loss: 5.7911e-04
# Epoch 89/100
# 58/58 [==============================] - 54s 920ms/step - loss: 5.8743e-04
# Epoch 90/100
# 58/58 [==============================] - 48s 830ms/step - loss: 5.8787e-04
# Epoch 91/100
# 58/58 [==============================] - 48s 831ms/step - loss: 4.7550e-04
# Epoch 92/100
# 58/58 [==============================] - 48s 831ms/step - loss: 4.8583e-04
# Epoch 93/100
# 58/58 [==============================] - 47s 816ms/step - loss: 5.1499e-04
# Epoch 94/100
# 58/58 [==============================] - 48s 828ms/step - loss: 5.1377e-04
# Epoch 95/100
# 58/58 [==============================] - 48s 826ms/step - loss: 5.9860e-04
# Epoch 96/100
# 58/58 [==============================] - 46s 790ms/step - loss: 4.7416e-04
# Epoch 97/100
# 58/58 [==============================] - 48s 825ms/step - loss: 5.2647e-04
# Epoch 98/100
# 58/58 [==============================] - 47s 816ms/step - loss: 4.8000e-04
# Epoch 99/100
# 58/58 [==============================] - 44s 765ms/step - loss: 6.2614e-04
# Epoch 100/100
# 58/58 [==============================] - 44s 757ms/step - loss: 4.8171e-04

# %%
test[['Value']].shape
# Out:
# (790, 1)

# %%
dataset_total = pd.concat((train['Value'], test['Value']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(test) - 365:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
y_test = []
for i in range(time_steps, len(test)+time_steps):
    X_test.append(inputs[i-time_steps:i, 0])
    y_test.append(inputs[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
uni_lstm_y_pred = brz_daily_uni_lstm.predict(X_test)
uni_lstm_y_pred = sc.inverse_transform(uni_lstm_y_pred)
# Out:
# 25/25 [==============================] - 10s 268ms/step

# %%
print("Mean Absolute Error: ", mean_absolute_error(uni_lstm_y_pred, test.values))
mse = mean_squared_error(uni_lstm_y_pred, test.values)
print("Mean Squared Error: ", mse)
print("Root Mean Squared Error: ",math.sqrt(mse))
# Out:
# Mean Absolute Error:  4.813887152765077
# Mean Squared Error:  32.5550698389193
# Root Mean Squared Error:  5.705705025579162

# %%
# Visualising the results
plt.figure(figsize=(20,5))
plt.plot(test.values, color = 'red', label = 'Real Hydro Energy Production')
plt.plot(uni_lstm_y_pred, color = 'blue', label = 'Predicted Hydro Energy Production')
plt.title('Brazil Hydro Energy Univariate LSTM Prediction')
plt.xlabel('Time')
plt.ylabel('Hydro Energy (GWh)')
plt.legend()
plt.show()

# %% [markdown]
# ## Multivariate LSTM

# %%
data = hydro_production_data['Brazil']

data.shape
# Out:
# (2982, 2)

# %%
X = data[['Precipitation', 'Value']]
y = data[['Value']]

X.head()
# Out:
#             Precipitation        Value
# Date
# 2015-01-01       0.248368  1107.850774
# 2015-01-02       0.250649  1106.774523
# 2015-01-03       0.252930  1105.698273
# 2015-01-04       0.255211  1104.622022
# 2015-01-05       0.257492  1103.545771

# %%
# Split the data into training and testing sets
split_date = '2021-01-01'
X_train, X_test = X[:split_date], X[split_date:]
y_train, y_test = y[:split_date], y[split_date:]

# %%
# Scale the features and target variables using MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler(feature_range=(0, 1))
y_scaler = MinMaxScaler(feature_range=(0, 1))
X_train, X_test = X_scaler.fit_transform(X_train), X_scaler.transform(X_test)
y_train, y_test = y_scaler.fit_transform(y_train), y_scaler.transform(y_test)

# %%
print(X_train.shape)
print(X_test.shape)
print()
print(y_train.shape)
print(y_test.shape)
# Out:
# (2193, 2)
# (790, 2)
#
# (2193, 1)
# (790, 1)

# %%
# Reshape the input data to fit the LSTM model (samples, time steps, features)
time_steps = 365  # Define the number of previous time steps to consider
n_features = X_train.shape[1]  # Number of features

# Creating a data structure with 365 timestamps and 1 output
X_train1 = []
y_train1 = []
for i in range(time_steps, len(X_train)):
    X_train1.append(X_train[i-time_steps:i])
    y_train1.append(y_train[i][0])
X_train1, y_train1 = np.array(X_train1), np.array(y_train1)

X_train1 = np.reshape(X_train1, (X_train1.shape[0], X_train1.shape[1], X_train1.shape[2]))

print(X_train1.shape)
# Out:
# (1828, 365, 2)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

brz_daily_multi_lstm = Sequential()
brz_daily_multi_lstm.add(LSTM(units = 64, return_sequences = True, input_shape=(time_steps, n_features)))
brz_daily_multi_lstm.add(Dropout(0.2))
brz_daily_multi_lstm.add(LSTM(units = 64, activation = 'relu', return_sequences = True))
brz_daily_multi_lstm.add(Dropout(0.2))
brz_daily_multi_lstm.add(LSTM(units = 64))
brz_daily_multi_lstm.add(Dropout(0.2))
brz_daily_multi_lstm.add(Dense(1))

# %%
brz_daily_multi_lstm.compile(optimizer='adam', loss='mean_squared_error')

brz_daily_multi_lstm.fit(X_train1, y_train1, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 58/58 [==============================] - 119s 775ms/step - loss: 0.0208
# Epoch 2/100
# 58/58 [==============================] - 49s 852ms/step - loss: 0.0046
# Epoch 3/100
# 58/58 [==============================] - 45s 770ms/step - loss: 0.0034
# Epoch 4/100
# 58/58 [==============================] - 44s 757ms/step - loss: 0.0026
# Epoch 5/100
# 58/58 [==============================] - 46s 787ms/step - loss: 0.0025
# Epoch 6/100
# 58/58 [==============================] - 45s 770ms/step - loss: 0.0023
# Epoch 7/100
# 58/58 [==============================] - 41s 705ms/step - loss: 0.0023
# Epoch 8/100
# 58/58 [==============================] - 40s 696ms/step - loss: 0.0026
# Epoch 9/100
# 58/58 [==============================] - 48s 830ms/step - loss: 0.0020
# Epoch 10/100
# 58/58 [==============================] - 52s 902ms/step - loss: 0.0024
# Epoch 11/100
# 58/58 [==============================] - 52s 899ms/step - loss: 0.0024
# Epoch 12/100
# 58/58 [==============================] - 54s 931ms/step - loss: 0.0018
# Epoch 13/100
# 58/58 [==============================] - 57s 980ms/step - loss: 0.0018
# Epoch 14/100
# 58/58 [==============================] - 58s 1s/step - loss: 0.0016
# Epoch 15/100
# 58/58 [==============================] - 56s 970ms/step - loss: 0.0016
# Epoch 16/100
# 58/58 [==============================] - 57s 991ms/step - loss: 0.0017
# Epoch 17/100
# 58/58 [==============================] - 53s 918ms/step - loss: 0.0015
# Epoch 18/100
# 58/58 [==============================] - 55s 952ms/step - loss: 0.0017
# Epoch 19/100
# 58/58 [==============================] - 57s 977ms/step - loss: 0.0016
# Epoch 20/100
# 58/58 [==============================] - 55s 940ms/step - loss: 0.0014
# Epoch 21/100
# 58/58 [==============================] - 59s 1s/step - loss: 0.0013
# Epoch 22/100
# 58/58 [==============================] - 52s 899ms/step - loss: 0.0016
# Epoch 23/100
# 58/58 [==============================] - 52s 904ms/step - loss: 0.0016
# Epoch 24/100
# 58/58 [==============================] - 50s 866ms/step - loss: 0.0014
# Epoch 25/100
# 58/58 [==============================] - 53s 921ms/step - loss: 0.0014
# Epoch 26/100
# 58/58 [==============================] - 51s 877ms/step - loss: 0.0013
# Epoch 27/100
# 58/58 [==============================] - 54s 940ms/step - loss: 0.0012
# Epoch 28/100
# 58/58 [==============================] - 54s 929ms/step - loss: 0.0012
# Epoch 29/100
# 58/58 [==============================] - 51s 879ms/step - loss: 0.0011
# Epoch 30/100
# 58/58 [==============================] - 52s 901ms/step - loss: 0.0011
# Epoch 31/100
# 58/58 [==============================] - 54s 932ms/step - loss: 0.0011
# Epoch 32/100
# 58/58 [==============================] - 53s 914ms/step - loss: 0.0010
# Epoch 33/100
# 58/58 [==============================] - 54s 939ms/step - loss: 0.0011
# Epoch 34/100
# 58/58 [==============================] - 52s 905ms/step - loss: 0.0012
# Epoch 35/100
# 58/58 [==============================] - 53s 908ms/step - loss: 9.7649e-04
# Epoch 36/100
# 58/58 [==============================] - 51s 888ms/step - loss: 0.0012
# Epoch 37/100
# 58/58 [==============================] - 54s 927ms/step - loss: 0.0010
# Epoch 38/100
# 58/58 [==============================] - 51s 879ms/step - loss: 0.0011
# Epoch 39/100
# 58/58 [==============================] - 53s 916ms/step - loss: 0.0011
# Epoch 40/100
# 58/58 [==============================] - 52s 894ms/step - loss: 0.0010
# Epoch 41/100
# 58/58 [==============================] - 51s 871ms/step - loss: 8.8485e-04
# Epoch 42/100
# 58/58 [==============================] - 52s 906ms/step - loss: 9.8902e-04
# Epoch 43/100
# 58/58 [==============================] - 52s 892ms/step - loss: 8.8541e-04
# Epoch 44/100
# 58/58 [==============================] - 51s 875ms/step - loss: 8.7568e-04
# Epoch 45/100
# 58/58 [==============================] - 51s 881ms/step - loss: 7.9968e-04
# Epoch 46/100
# 58/58 [==============================] - 52s 907ms/step - loss: 9.0022e-04
# Epoch 47/100
# 58/58 [==============================] - 54s 936ms/step - loss: 9.5968e-04
# Epoch 48/100
# 58/58 [==============================] - 55s 942ms/step - loss: 7.8374e-04
# Epoch 49/100
# 58/58 [==============================] - 54s 931ms/step - loss: 7.9777e-04
# Epoch 50/100
# 58/58 [==============================] - 52s 896ms/step - loss: 8.9952e-04
# Epoch 51/100
# 58/58 [==============================] - 55s 946ms/step - loss: 9.9932e-04
# Epoch 52/100
# 58/58 [==============================] - 53s 917ms/step - loss: 8.0884e-04
# Epoch 53/100
# 58/58 [==============================] - 50s 857ms/step - loss: 8.7314e-04
# Epoch 54/100
# 58/58 [==============================] - 53s 921ms/step - loss: 9.3918e-04
# Epoch 55/100
# 58/58 [==============================] - 51s 883ms/step - loss: 9.9001e-04
# Epoch 56/100
# 58/58 [==============================] - 54s 934ms/step - loss: 7.9056e-04
# Epoch 57/100
# 58/58 [==============================] - 51s 884ms/step - loss: 7.0603e-04
# Epoch 58/100
# 58/58 [==============================] - 52s 905ms/step - loss: 7.0854e-04
# Epoch 59/100
# 58/58 [==============================] - 53s 919ms/step - loss: 8.3599e-04
# Epoch 60/100
# 58/58 [==============================] - 52s 895ms/step - loss: 9.4652e-04
# Epoch 61/100
# 58/58 [==============================] - 52s 883ms/step - loss: 6.4667e-04
# Epoch 62/100
# 58/58 [==============================] - 52s 901ms/step - loss: 6.4667e-04
# Epoch 63/100
# 58/58 [==============================] - 51s 875ms/step - loss: 7.4382e-04
# Epoch 64/100
# 58/58 [==============================] - 51s 884ms/step - loss: 6.5591e-04
# Epoch 65/100
# 58/58 [==============================] - 54s 942ms/step - loss: 7.0470e-04
# Epoch 66/100
# 58/58 [==============================] - 53s 905ms/step - loss: 6.9198e-04
# Epoch 67/100
# 58/58 [==============================] - 52s 897ms/step - loss: 7.7595e-04
# Epoch 68/100
# 58/58 [==============================] - 52s 893ms/step - loss: 6.3009e-04
# Epoch 69/100
# 58/58 [==============================] - 51s 879ms/step - loss: 8.0788e-04
# Epoch 70/100
# 58/58 [==============================] - 50s 866ms/step - loss: 6.3707e-04
# Epoch 71/100
# 58/58 [==============================] - 51s 883ms/step - loss: 6.0825e-04
# Epoch 72/100
# 58/58 [==============================] - 53s 908ms/step - loss: 6.8172e-04
# Epoch 73/100
# 58/58 [==============================] - 50s 860ms/step - loss: 5.6474e-04
# Epoch 74/100
# 58/58 [==============================] - 50s 865ms/step - loss: 6.2299e-04
# Epoch 75/100
# 58/58 [==============================] - 46s 790ms/step - loss: 6.0958e-04
# Epoch 76/100
# 58/58 [==============================] - 47s 806ms/step - loss: 6.5243e-04
# Epoch 77/100
# 58/58 [==============================] - 44s 767ms/step - loss: 7.4144e-04
# Epoch 78/100
# 58/58 [==============================] - 46s 790ms/step - loss: 5.1266e-04
# Epoch 79/100
# 58/58 [==============================] - 52s 894ms/step - loss: 5.3828e-04
# Epoch 80/100
# 58/58 [==============================] - 52s 902ms/step - loss: 6.0086e-04
# Epoch 81/100
# 58/58 [==============================] - 56s 965ms/step - loss: 6.2425e-04
# Epoch 82/100
# 58/58 [==============================] - 51s 885ms/step - loss: 6.2387e-04
# Epoch 83/100
# 58/58 [==============================] - 53s 919ms/step - loss: 5.7698e-04
# Epoch 84/100
# 58/58 [==============================] - 52s 904ms/step - loss: 5.2227e-04
# Epoch 85/100
# 58/58 [==============================] - 54s 939ms/step - loss: 5.4172e-04
# Epoch 86/100
# 58/58 [==============================] - 51s 889ms/step - loss: 5.3516e-04
# Epoch 87/100
# 58/58 [==============================] - 51s 879ms/step - loss: 5.2873e-04
# Epoch 88/100
# 58/58 [==============================] - 52s 897ms/step - loss: 5.3949e-04
# Epoch 89/100
# 58/58 [==============================] - 50s 858ms/step - loss: 5.6000e-04
# Epoch 90/100
# 58/58 [==============================] - 53s 916ms/step - loss: 5.8319e-04
# Epoch 91/100
# 58/58 [==============================] - 52s 894ms/step - loss: 5.1796e-04
# Epoch 92/100
# 58/58 [==============================] - 51s 880ms/step - loss: 5.1091e-04
# Epoch 93/100
# 58/58 [==============================] - 44s 769ms/step - loss: 4.9103e-04
# Epoch 94/100
# 58/58 [==============================] - 45s 778ms/step - loss: 6.2018e-04
# Epoch 95/100
# 58/58 [==============================] - 45s 779ms/step - loss: 5.1605e-04
# Epoch 96/100
# 58/58 [==============================] - 49s 840ms/step - loss: 4.9592e-04
# Epoch 97/100
# 58/58 [==============================] - 58s 1s/step - loss: 6.7810e-04
# Epoch 98/100
# 58/58 [==============================] - 55s 953ms/step - loss: 5.1749e-04
# Epoch 99/100
# 58/58 [==============================] - 56s 966ms/step - loss: 5.5650e-04
# Epoch 100/100
# 58/58 [==============================] - 55s 953ms/step - loss: 4.8280e-04

# %%
X_total_data = X
inputs = X_total_data[len(X_total_data) - len(X_test) - 365:]
inputs = X_scaler.transform(inputs)

X_test1 = []
for i in range(time_steps, len(X_test)+time_steps):
    X_test1.append(inputs[i-time_steps:i])
X_test1 = np.array(X_test1)
X_test1 = np.reshape(X_test1, (X_test1.shape[0], X_test1.shape[1], X_test1.shape[2]))

multi_lstm_y_pred = brz_daily_multi_lstm.predict(X_test1)
multi_lstm_y_pred = y_scaler.inverse_transform(multi_lstm_y_pred)
real_value = y_scaler.inverse_transform(y_test)
# Out:
# 25/25 [==============================] - 9s 239ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
print("Mean Absolute Error: ", mean_absolute_error(multi_lstm_y_pred, real_value))
mse = mean_squared_error(multi_lstm_y_pred, real_value)
print("Mean Squared Error: ", mse)
import math
print("Root Mean Squared Error: ",math.sqrt(mse))
# Out:
# Mean Absolute Error:  7.077657602192497
# Mean Squared Error:  104.2865977729261
# Root Mean Squared Error:  10.212080971718061

# %%
# Visualising the results
plt.figure(figsize=(20,5))
plt.plot(real_value, color='red', label='Real Value')
plt.plot(multi_lstm_y_pred, color='blue', label='Predicted Value')
plt.title('Brazil Hydro Energy Multivariate LSTM Prediction')
plt.xlabel('Time')
plt.ylabel('Hydro Energy (GWh)')
plt.legend()
plt.show()

# %% [markdown]
# # Overview

# %%
# Visualising the results
plt.figure(figsize=(20,5))
plt.plot(real_value, color='black', label='Real Value')
plt.plot(predictions.rx('mean')[0], color='grey', linestyle='--', label='ARIMA')
plt.plot(svr_y_pred, color='green', linestyle='--', label='SVR')
plt.plot(ann_y_pred, color='orange', linestyle='--', label='ANN')
plt.plot(uni_lstm_y_pred, color='red', linestyle='--', label='Univaraite LSTM')
plt.plot(multi_lstm_y_pred, color='blue', linestyle='--', label='Multivaraite LSTM')
plt.title('Brazil Hydro Energy Prediction')
plt.xlabel('Time')
plt.ylabel('Hydro Energy (GWh)')
plt.legend()
plt.show()

# %% [markdown]
# # Save Best Model

# %%
brz_daily_uni_lstm.save('brz_hydro_best_uni_lstm.h5')
# Out:
# C:\Users\Acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
